# %%
import pandas as pd
import pickle
import time
import os
import re

# %%
with open('ev_test.pkl','rb') as f:
    df = pickle.load(f)

# %%
df.to_csv('check1.csv',encoding = 'cp949')

# %%
df['가격'] = df['가격'].str.replace('신차금리비교', '')

# %%
df = df.replace('0','미공시')

# %%
df
# Out:
#                       차종                가격                   연료  \
# 0           2024 테슬라 모델S  11,525~12,554만원               전기 내차정비
# 1           2024 테슬라 모델3    5,199~5,999만원               전기 내차정비
# 2   2024 메르세데스-AMG S클...         29,900만원   전기, 가솔린, 하이브리드 내차정비
# 3       2024 대창모터스 다니고 W          4,560만원               전기 내차정비
# 4       2024 대창모터스 다니고 T    4,360~4,510만원               전기 내차정비
# ..                   ...               ...                  ...
# 86      2022 페라리 296 GTB         39,800만원   전기, 가솔린, 하이브리드 내차정비
# 87   2022 DS 3 크로스백 E-텐스          5,790만원               전기 내차정비
# 88      2022 아우디 e-트론 GT  14,332~16,632만원               전기 내차정비
# 89   2022 아우디 RS e-트론 GT         20,632만원               전기 내차정비
# 90          2021 맥라렌 아투라         29,900만원   전기, 가솔린, 하이브리드 내차정비
#
#                    주행거리                                     연비  \
# 0     474~555km 1회 충전 시    복합 4.1~4.8km/kWh 도심 4.2~5, 고속 4~4.6
# 1     382~488km 1회 충전 시  복합 5.5~5.7km/kWh 도심 5.7~6, 고속 5.2~5.3
# 2    복합 7.9km/ℓ 도심 , 고속             802hp/615hp/138kW 합산/엔진/모터
# 3         186km 1회 충전 시                             복합 도심 , 고속
# 4     170~181km 1회 충전 시                             복합 도심 , 고속
# ..                  ...                                    ...
# 86  복합 15.6km/ℓ 도심 , 고속             830hp/663hp/122kW 합산/엔진/모터
# 87        260km 1회 충전 시            복합 4.9km/kWh 도심 5.2, 고속 4.5
# 88        362km 1회 충전 시            복합 3.7km/kWh 도심 3.5, 고속 3.9
# 89        336km 1회 충전 시            복합 3.4km/kWh 도심 3.3, 고속 3.4
# 90   복합 7.7km/ℓ 도심 , 고속              680hp/585hp/70kW 합산/엔진/모터
#
#                   용량                                출력
# 0         100kWh 배터리  500~760kW 모터 670~1,018hp (단순환산치)
# 1   59.6~81.6kWh 배터리    208~366kW 모터 279~490hp (단순환산치)
# 2                  0                           V8 트윈터보
# 3        57.7kWh 배터리              60kW 모터 80hp (단순환산치)
# 4        57.7kWh 배터리              60kW 모터 80hp (단순환산치)
# ..               ...                               ...
# 86                 0                           V6 자연흡기
# 87         50kWh 배터리            100kW 모터 134hp (단순환산치)
# 88       93.4kWh 배터리            390kW 모터 523hp (단순환산치)
# 89       93.4kWh 배터리            475kW 모터 637hp (단순환산치)
# 90                 0                           V6 트윈터보
#
# [91 rows x 7 columns]

# %%
df2 = pd.read_csv('total_ev_power_demand.csv')

# %%
df2.drop('ID', axis =1, inplace = True)

# %%
df2.groupby(['YMD','SGG_NM']).sum()
# Out:
#                    EV_PWR_DEMAND_25  EV_PWR_DEMAND_50  EV_PWR_DEMAND_75
# YMD        SGG_NM
# 2022-02-01 강원 강릉시          24174.80          25262.20          28078.60
#            강원 고성군           5147.14           5929.99           6501.83
#            강원 동해시          16570.80          18122.10          40690.70
#            강원 삼척시          12587.10          12619.30          12695.20
#            강원 속초시          21754.30          23110.30          24899.20
# ...                             ...               ...               ...
# 2023-12-01 충북 제천시          14871.00          15630.80          18588.90
#            충북 증평군           3582.51           4578.46           5210.65
#            충북 진천군          23037.50          23476.40          24952.30
#            충북 청주시         207561.00         216169.00         233296.00
#            충북 충주시          77698.60          91270.00          93646.00
#
# [5221 rows x 3 columns]

# %%
df3 = pd.read_csv('check1.csv',encoding = 'cp949')

# %%
df3['가격'] = df['가격'].str.replace('신차금리비교','')

# %%
df3.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
df3
# Out:
#                       차종                가격                   연료  \
# 0           2024 테슬라 모델S  11,525~12,554만원               전기 내차정비
# 1           2024 테슬라 모델3    5,199~5,999만원               전기 내차정비
# 2   2024 메르세데스-AMG S클...         29,900만원   전기, 가솔린, 하이브리드 내차정비
# 3       2024 대창모터스 다니고 W          4,560만원               전기 내차정비
# 4       2024 대창모터스 다니고 T    4,360~4,510만원               전기 내차정비
# ..                   ...               ...                  ...
# 86      2022 페라리 296 GTB         39,800만원   전기, 가솔린, 하이브리드 내차정비
# 87   2022 DS 3 크로스백 E-텐스          5,790만원               전기 내차정비
# 88      2022 아우디 e-트론 GT  14,332~16,632만원               전기 내차정비
# 89   2022 아우디 RS e-트론 GT         20,632만원               전기 내차정비
# 90          2021 맥라렌 아투라         29,900만원   전기, 가솔린, 하이브리드 내차정비
#
#                  주행거리                                     연비  \
# 0   474~555km 1회 충전 시    복합 4.1~4.8km/kWh 도심 4.2~5, 고속 4~4.6
# 1   382~488km 1회 충전 시  복합 5.5~5.7km/kWh 도심 5.7~6, 고속 5.2~5.3
# 2                   0                     복합 7.9km/ℓ 도심 , 고속
# 3       186km 1회 충전 시                             복합 도심 , 고속
# 4   170~181km 1회 충전 시                             복합 도심 , 고속
# ..                ...                                    ...
# 86                  0                    복합 15.6km/ℓ 도심 , 고속
# 87      260km 1회 충전 시            복합 4.9km/kWh 도심 5.2, 고속 4.5
# 88      362km 1회 충전 시            복합 3.7km/kWh 도심 3.5, 고속 3.9
# 89      336km 1회 충전 시            복합 3.4km/kWh 도심 3.3, 고속 3.4
# 90                  0                     복합 7.7km/ℓ 도심 , 고속
#
#                   용량                                출력
# 0         100kWh 배터리  500~760kW 모터 670~1,018hp (단순환산치)
# 1   59.6~81.6kWh 배터리    208~366kW 모터 279~490hp (단순환산치)
# 2                  0        802hp/615hp/138kW 합산/엔진/모터
# 3        57.7kWh 배터리              60kW 모터 80hp (단순환산치)
# 4        57.7kWh 배터리              60kW 모터 80hp (단순환산치)
# ..               ...                               ...
# 86                 0        830hp/663hp/122kW 합산/엔진/모터
# 87         50kWh 배터리            100kW 모터 134hp (단순환산치)
# 88       93.4kWh 배터리            390kW 모터 523hp (단순환산치)
# 89       93.4kWh 배터리            475kW 모터 637hp (단순환산치)
# 90                 0         680hp/585hp/70kW 합산/엔진/모터
#
# [91 rows x 7 columns]

# %%
df3.to_pickle('last.pkl')

# %%
with open('last.pkl','rb') as f:
    ev_li = pickle.load(f)

# %%
idx = ev_li[ev_li['연료'].str.contains('하이브리드')].index

# %%
ev_li = ev_li.drop(idx)

# %%
ev_li['가격'] = ev_li['가격'].str.replace(' ', '')

# %%
ev_li.rename(columns = {'출력' : '출력(단순환산치)'},inplace = True)

# %%
ev_li
# Out:
#                      차종              가격   연료 주행거리(1회 충전 시)  \
# 0          2024 테슬라 모델S  11,525~12,554   전기     474~555km
# 1          2024 테슬라 모델3    5,199~5,999   전기     382~488km
# 3      2024 대창모터스 다니고 W          4,560   전기         186km
# 4      2024 대창모터스 다니고 T    4,360~4,510   전기     170~181km
# 5      2024 대창모터스 다니고 R    4,780~5,780   전기         186km
# ..                  ...             ...  ...           ...
# 84     2022 SS모터스 젤라 EV          4,180   전기         194km
# 85         2022 코란도 이모션    3,880~4,390   전기         307km
# 87  2022 DS 3 크로스백 E-텐스          5,790   전기         260km
# 88     2022 아우디 e-트론 GT  14,332~16,632   전기         362km
# 89  2022 아우디 RS e-트론 GT         20,632   전기         336km
#
#                                        연비        용량(배터리)  \
# 0     복합 4.1~4.8km/kWh 도심 4.2~5, 고속 4~4.6        100kWh
# 1   복합 5.5~5.7km/kWh 도심 5.7~6, 고속 5.2~5.3  59.6~81.6kWh
# 3                                       0       57.7kWh
# 4                                       0       57.7kWh
# 5                                       0       57.7kWh
# ..                                    ...            ...
# 84            복합 2.6km/kWh 도심 2.9, 고속 2.3       66.8kWh
# 85            복합 4.9km/kWh 도심 5.4, 고속 4.4       61.5kWh
# 87            복합 4.9km/kWh 도심 5.2, 고속 4.5         50kWh
# 88            복합 3.7km/kWh 도심 3.5, 고속 3.9       93.4kWh
# 89            복합 3.4km/kWh 도심 3.3, 고속 3.4       93.4kWh
#
#                     출력(단순환산치)
# 0   500~760kW 모터 670~1,018hp
# 1     208~366kW 모터 279~490hp
# 3               60kW 모터 80hp
# 4               60kW 모터 80hp
# 5               60kW 모터 80hp
# ..                        ...
# 84            100kW 모터 134hp
# 85            140kW 모터 188hp
# 87            100kW 모터 134hp
# 88            390kW 모터 523hp
# 89            475kW 모터 637hp
#
# [69 rows x 7 columns]

# %%
ev_li_1 = ev_li.copy()

# %%
ev_li['가격'] = ev_li['가격'].str.replace('시승하기AD', '')

# %%
def calculate_average(row):
    prices = row['가격'].split('~')
    if len(prices) == 1:
        return int(prices[0])
    else:
        return int((int(prices[0]) + int(prices[1])) / 2)

# %%
ev_li['가격'] = ev_li.apply(calculate_average, axis=1)

# %%
ev_li['가격'] = ev_li['가격'].astype(str)

# %%
ev_li['가격'] = ev_li['가격'] +'만원'

# %%
ev_li.to_csv('check3.csv',encoding= 'cp949',index = False)

# %%
ev = pd.read_csv('check3.csv',encoding = 'cp949')

# %%
ev
# Out:
#                      차종       가격   연료 주행거리(1회 충전 시)  \
# 0          2024 테슬라 모델S  12039만원  전기     474~555km
# 1          2024 테슬라 모델3   5599만원  전기     382~488km
# 2      2024 대창모터스 다니고 W   4560만원  전기         186km
# 3      2024 대창모터스 다니고 T   4435만원  전기     170~181km
# 4      2024 대창모터스 다니고 R   5280만원  전기         186km
# ..                  ...      ...  ...           ...
# 64     2022 SS모터스 젤라 EV   4180만원  전기         194km
# 65         2022 코란도 이모션   4135만원  전기         307km
# 66  2022 DS 3 크로스백 E-텐스   5790만원  전기         260km
# 67     2022 아우디 e-트론 GT  15482만원  전기         362km
# 68  2022 아우디 RS e-트론 GT  20632만원  전기         336km
#
#                                        연비        용량(배터리)  \
# 0     복합 4.1~4.8km/kWh 도심 4.2~5, 고속 4~4.6        100kWh
# 1   복합 5.5~5.7km/kWh 도심 5.7~6, 고속 5.2~5.3  59.6~81.6kWh
# 2                                       0       57.7kWh
# 3                                       0       57.7kWh
# 4                                       0       57.7kWh
# ..                                    ...            ...
# 64            복합 2.6km/kWh 도심 2.9, 고속 2.3       66.8kWh
# 65            복합 4.9km/kWh 도심 5.4, 고속 4.4       61.5kWh
# 66            복합 4.9km/kWh 도심 5.2, 고속 4.5         50kWh
# 67            복합 3.7km/kWh 도심 3.5, 고속 3.9       93.4kWh
# 68            복합 3.4km/kWh 도심 3.3, 고속 3.4       93.4kWh
#
#                     출력(단순환산치)
# 0   500~760kW 모터 670~1,018hp
# 1     208~366kW 모터 279~490hp
# 2               60kW 모터 80hp
# 3               60kW 모터 80hp
# 4               60kW 모터 80hp
# ..                        ...
# 64            100kW 모터 134hp
# 65            140kW 모터 188hp
# 66            100kW 모터 134hp
# 67            390kW 모터 523hp
# 68            475kW 모터 637hp
#
# [69 rows x 7 columns]

# %%
ev['주행거리(1회 충전 시)'] = ev['주행거리(1회 충전 시)'].str.replace('km', '')

# %%
def calculate_average(row):
    reach = row['주행거리(1회 충전 시)'].split('~')
    if len(reach) == 1:
        return int(reach[0])
    else:
        return int((int(reach[0]) + int(reach[1])) / 2)

# %%
ev['주행거리(1회 충전 시)'] = ev.apply(calculate_average, axis=1)

# %%
ev['주행거리(1회 충전 시)'] = ev['주행거리(1회 충전 시)'].astype(str)

# %%
ev['주행거리(1회 충전 시)'] = ev['주행거리(1회 충전 시)'] +'km'

# %%
ev
# Out:
#                      차종       가격   연료 주행거리(1회 충전 시)  \
# 0          2024 테슬라 모델S  12039만원  전기          514km
# 1          2024 테슬라 모델3   5599만원  전기          435km
# 2      2024 대창모터스 다니고 W   4560만원  전기          186km
# 3      2024 대창모터스 다니고 T   4435만원  전기          175km
# 4      2024 대창모터스 다니고 R   5280만원  전기          186km
# ..                  ...      ...  ...           ...
# 64     2022 SS모터스 젤라 EV   4180만원  전기          194km
# 65         2022 코란도 이모션   4135만원  전기          307km
# 66  2022 DS 3 크로스백 E-텐스   5790만원  전기          260km
# 67     2022 아우디 e-트론 GT  15482만원  전기          362km
# 68  2022 아우디 RS e-트론 GT  20632만원  전기          336km
#
#                                        연비        용량(배터리)  \
# 0     복합 4.1~4.8km/kWh 도심 4.2~5, 고속 4~4.6        100kWh
# 1   복합 5.5~5.7km/kWh 도심 5.7~6, 고속 5.2~5.3  59.6~81.6kWh
# 2                                       0       57.7kWh
# 3                                       0       57.7kWh
# 4                                       0       57.7kWh
# ..                                    ...            ...
# 64            복합 2.6km/kWh 도심 2.9, 고속 2.3       66.8kWh
# 65            복합 4.9km/kWh 도심 5.4, 고속 4.4       61.5kWh
# 66            복합 4.9km/kWh 도심 5.2, 고속 4.5         50kWh
# 67            복합 3.7km/kWh 도심 3.5, 고속 3.9       93.4kWh
# 68            복합 3.4km/kWh 도심 3.3, 고속 3.4       93.4kWh
#
#                     출력(단순환산치)
# 0   500~760kW 모터 670~1,018hp
# 1     208~366kW 모터 279~490hp
# 2               60kW 모터 80hp
# 3               60kW 모터 80hp
# 4               60kW 모터 80hp
# ..                        ...
# 64            100kW 모터 134hp
# 65            140kW 모터 188hp
# 66            100kW 모터 134hp
# 67            390kW 모터 523hp
# 68            475kW 모터 637hp
#
# [69 rows x 7 columns]

# %%
print(ev['연비'])
# Out:
# 0       복합 4.1~4.8km/kWh 도심 4.2~5, 고속 4~4.6
# 1     복합 5.5~5.7km/kWh 도심 5.7~6, 고속 5.2~5.3
# 2                                         0
# 3                                         0
# 4                                         0
#                       ...
# 64              복합 2.6km/kWh 도심 2.9, 고속 2.3
# 65              복합 4.9km/kWh 도심 5.4, 고속 4.4
# 66              복합 4.9km/kWh 도심 5.2, 고속 4.5
# 67              복합 3.7km/kWh 도심 3.5, 고속 3.9
# 68              복합 3.4km/kWh 도심 3.3, 고속 3.4
# Name: 연비, Length: 69, dtype: object

# %%
#pattern = r'복합 [0-9]*\.[0-9]+~[0-9]*\.[0-9]+[A-Za-z]+/[A-Za-z]'
#pattern = r'복합 [0-9]+~[0-9]*\.[0-9]+[A-Za-z]+/[A-Za-z]'
pattern = r'복합 [0-9]*\.[0-9]+~[A-Za-z0-9]+/[A-Za-z]'
ev['연비'] = ev['연비'].apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else x)

# %%
ev
# Out:
#                      차종       가격   연료 주행거리(1회 충전 시)              연비  \
# 0          2024 테슬라 모델S  12039만원  전기          514km  복합 4.1~4.8km/k
# 1          2024 테슬라 모델3   5599만원  전기          435km  복합 5.5~5.7km/k
# 2      2024 대창모터스 다니고 W   4560만원  전기          186km               0
# 3      2024 대창모터스 다니고 T   4435만원  전기          175km               0
# 4      2024 대창모터스 다니고 R   5280만원  전기          186km               0
# ..                  ...      ...  ...           ...             ...
# 64     2022 SS모터스 젤라 EV   4180만원  전기          194km      복합 2.6km/k
# 65         2022 코란도 이모션   4135만원  전기          307km      복합 4.9km/k
# 66  2022 DS 3 크로스백 E-텐스   5790만원  전기          260km      복합 4.9km/k
# 67     2022 아우디 e-트론 GT  15482만원  전기          362km      복합 3.7km/k
# 68  2022 아우디 RS e-트론 GT  20632만원  전기          336km      복합 3.4km/k
#
#           용량(배터리)                  출력(단순환산치)
# 0         100kWh   500~760kW 모터 670~1,018hp
# 1   59.6~81.6kWh     208~366kW 모터 279~490hp
# 2        57.7kWh               60kW 모터 80hp
# 3        57.7kWh               60kW 모터 80hp
# 4        57.7kWh               60kW 모터 80hp
# ..            ...                        ...
# 64       66.8kWh             100kW 모터 134hp
# 65       61.5kWh             140kW 모터 188hp
# 66         50kWh             100kW 모터 134hp
# 67       93.4kWh             390kW 모터 523hp
# 68       93.4kWh             475kW 모터 637hp
#
# [69 rows x 7 columns]

# %%
ev[ev['연비'].str.contains('도심')]
# Out:
# Empty DataFrame
# Columns: [차종, 가격, 연료, 주행거리(1회 충전 시), 연비, 용량(배터리), 출력(단순환산치)]
# Index: []

# %%
ev['연비'] = ev['연비'].str.replace('km/k', '')

# %%
ev
# Out:
#                      차종       가격   연료 주행거리(1회 충전 시)       연비        용량(배터리)  \
# 0          2024 테슬라 모델S  12039만원  전기          514km  4.1~4.8        100kWh
# 1          2024 테슬라 모델3   5599만원  전기          435km  5.5~5.7  59.6~81.6kWh
# 2      2024 대창모터스 다니고 W   4560만원  전기          186km        0       57.7kWh
# 3      2024 대창모터스 다니고 T   4435만원  전기          175km        0       57.7kWh
# 4      2024 대창모터스 다니고 R   5280만원  전기          186km        0       57.7kWh
# ..                  ...      ...  ...           ...      ...            ...
# 64     2022 SS모터스 젤라 EV   4180만원  전기          194km      2.6       66.8kWh
# 65         2022 코란도 이모션   4135만원  전기          307km      4.9       61.5kWh
# 66  2022 DS 3 크로스백 E-텐스   5790만원  전기          260km      4.9         50kWh
# 67     2022 아우디 e-트론 GT  15482만원  전기          362km      3.7       93.4kWh
# 68  2022 아우디 RS e-트론 GT  20632만원  전기          336km      3.4       93.4kWh
#
#                     출력(단순환산치)
# 0   500~760kW 모터 670~1,018hp
# 1     208~366kW 모터 279~490hp
# 2               60kW 모터 80hp
# 3               60kW 모터 80hp
# 4               60kW 모터 80hp
# ..                        ...
# 64            100kW 모터 134hp
# 65            140kW 모터 188hp
# 66            100kW 모터 134hp
# 67            390kW 모터 523hp
# 68            475kW 모터 637hp
#
# [69 rows x 7 columns]

# %%
ev['연비'] = ev['연비'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 ev['연비'] = ev['연비'].astype(float)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '4.1~4.8'

# %%
pd.read_

# %%
ev.to_csv('check4.csv',encoding = 'cp949')

# %%
def calculate_average(row):
    rat = row['연비'].split('~')
    if len(rat) == 1:
        return float(rat[0])
    else:
        return float((float(rat[0]) + float(rat[1])) / 2)

# %%
ev['연비'] = ev.apply(calculate_average, axis=1)

# %%
ev1 = ev.copy()

# %%
ev = ev1.copy()

# %%
ev['연비'] = ev['연비'].astype(float)

# %%
ev['연비'] = ev['연비'].apply(lambda x: "{:.1f}".format(float(x)))

# %%
ev.to_csv('checkpoint1.csv',encoding = 'cp949')

# %%
ev['연비'] = ev['연비'].astype(str)

# %%
ev['연비'] = ev['연비'] + 'km/kWh'

# %%
ev['용량(배터리)'] = ev['용량(배터리)'].str.replace(' 배터리','')

# %%
ev
# Out:
#                      차종       가격   연료 주행거리(1회 충전 시)         연비     용량(배터리)  \
# 0          2024 테슬라 모델S  12039만원  전기          514km  4.4km/kWh        100
# 1          2024 테슬라 모델3   5599만원  전기          435km  5.6km/kWh  59.6~81.6
# 2      2024 대창모터스 다니고 W   4560만원  전기          186km  0.0km/kWh       57.7
# 3      2024 대창모터스 다니고 T   4435만원  전기          175km  0.0km/kWh       57.7
# 4      2024 대창모터스 다니고 R   5280만원  전기          186km  0.0km/kWh       57.7
# ..                  ...      ...  ...           ...        ...         ...
# 64     2022 SS모터스 젤라 EV   4180만원  전기          194km  2.6km/kWh       66.8
# 65         2022 코란도 이모션   4135만원  전기          307km  4.9km/kWh       61.5
# 66  2022 DS 3 크로스백 E-텐스   5790만원  전기          260km  4.9km/kWh         50
# 67     2022 아우디 e-트론 GT  15482만원  전기          362km  3.7km/kWh       93.4
# 68  2022 아우디 RS e-트론 GT  20632만원  전기          336km  3.4km/kWh       93.4
#
#                     출력(단순환산치)
# 0   500~760kW 모터 670~1,018hp
# 1     208~366kW 모터 279~490hp
# 2               60kW 모터 80hp
# 3               60kW 모터 80hp
# 4               60kW 모터 80hp
# ..                        ...
# 64            100kW 모터 134hp
# 65            140kW 모터 188hp
# 66            100kW 모터 134hp
# 67            390kW 모터 523hp
# 68            475kW 모터 637hp
#
# [69 rows x 7 columns]

# %%
def calculate_average(row):
    bat = row['용량(배터리)'].split('~')
    if len(bat) == 1:
        return float(bat[0])
    else:
        return float((float(bat[0]) + float(bat[1])) / 2)

# %%
ev['용량(배터리)'] = ev.apply(calculate_average, axis=1)

# %%
ev['용량(배터리)'] = ev['용량(배터리)'].apply(lambda x: "{:.1f}".format(float(x)))

# %%
ev['용량(배터리)'] = ev['용량(배터리)'].astype(str)

# %%
ev['용량(배터리)'] = ev['용량(배터리)'].str.replace('.0','')

# %%
ev['용량(배터리)'] = ev['용량(배터리)'] + 'kWh'

# %%
ev.to_csv('checkpoint3.csv',encoding = 'cp949',index = False)

# %%
ev_3 = pd.read_csv('checkpoint2.csv',encoding = 'cp949')

# %%
ev_3.drop('Unnamed: 0',axis =1, inplace = True)

# %%
ev_3.drop('출력(단순환산치)', axis = 1, inplace = True)

# %%
ev_3.to_csv('ev_list.csv',encoding = 'cp949',index = False)

# %%
df = pd.read_csv('total_ev_power_demand.csv',encoding = 'utf8')

# %%
df.drop('ID', axis = 1, inplace = True)

# %%
df.groupby(['YMD','SGG_NM'])
# Out:
#              YMD  EV_PWR_DEMAND_25  EV_PWR_DEMAND_50  EV_PWR_DEMAND_75  SGG_NM
# 0     2022-02-01          24174.80          25262.20          28078.60  강원 강릉시
# 1     2022-02-01           5147.14           5929.99           6501.83  강원 고성군
# 2     2022-02-01          16570.80          18122.10          40690.70  강원 동해시
# 3     2022-02-01          12587.10          12619.30          12695.20  강원 삼척시
# 4     2022-02-01          21754.30          23110.30          24899.20  강원 속초시
# ...          ...               ...               ...               ...     ...
# 5216  2023-12-01          14871.00          15630.80          18588.90  충북 제천시
# 5217  2023-12-01           3582.51           4578.46           5210.65  충북 증평군
# 5218  2023-12-01          23037.50          23476.40          24952.30  충북 진천군
# 5219  2023-12-01         207561.00         216169.00         233296.00  충북 청주시
# 5220  2023-12-01          77698.60          91270.00          93646.00  충북 충주시
#
# [5221 rows x 5 columns]

# %%
df_charge = pd.read_excel('201007_202404_.xls')

# %%
df_charge
# Out:
#           년월     서울     부산     대구     인천     광주     대전    울산    세종      경기  \
# 0    2024-02  72981  35022  30414  41189  12571  18003  7888  4475  115414
# 1    2024-01  72877  34789  30396  40845  12529  17981  7875  4430  114735
# 2    2023-12  72937  34643  30396  40397  12538  17889  7838  4393  114117
# 3    2023-06  59327  22063  24161  26242   9096  14476  5061  3034   77648
# 4    2022-12  59327  22063  24161  26242   9096  14476  5061  3034   77648
# ..       ...    ...    ...    ...    ...    ...    ...   ...   ...     ...
# 149  2010-11     34      0      0      2      1      2     0     0       3
# 150  2010-10     33      0      0      0      1      2     0     0       2
# 151  2010-09     31      0      0      0      1      0     0     0       1
# 152  2010-08     20      0      0      0      1      0     0     0       0
# 153  2010-07     19      0      0      0      1      0     0     0       0
#
#         강원     충북     충남     전북     전남     경북     경남     제주      합계
# 0    18240  20009  24055  19804  24336  26985  36534  39535  547455
# 1    18247  20003  24194  19827  24276  26934  36410  39439  545787
# 2    18236  19972  24130  19795  24200  26776  36225  39418  543900
# 3    14012  15140  16611  12727  15387  19154  22740  32976  389855
# 4    14012  15140  16611  12727  15387  19154  22740  32976  389855
# ..     ...    ...    ...    ...    ...    ...    ...    ...     ...
# 149      0      0      2      0      0      1      0      0      45
# 150      0      0      1      0      0      1      0      0      40
# 151      0      0      1      0      0      1      0      0      35
# 152      0      0      1      0      0      1      0      0      23
# 153      0      0      0      0      0      1      0      0      21
#
# [154 rows x 19 columns]

# %%
li1 = ['2010-12','2011-12','2012-12','2013-12','2014-12','2015-12','2016-12','2017-12','2018-12','2019-12','2020-12','2021-12','2022-12','2023-12','2024-02']

# %%
new_df = df_charge[df_charge['년월'].isin(li1)]

# %%
new_df
# Out:
#           년월     서울     부산     대구     인천     광주     대전    울산    세종      경기  \
# 0    2024-02  72981  35022  30414  41189  12571  18003  7888  4475  115414
# 2    2023-12  72937  34643  30396  40397  12538  17889  7838  4393  114117
# 4    2022-12  59327  22063  24161  26242   9096  14476  5061  3034   77648
# 16   2021-12  40564  12375  16185  12820   5194   7701  3166  1859   39958
# 28   2020-12  23393   5355  12630   5366   3210   4469  2274  1148   20477
# 40   2019-12  14952   3216  11313   2598   2464   2555  1447   903   11750
# 52   2018-12   9564   1567   6605   1284   1447   1334   847   394    6383
# 64   2017-12   4797    816   2005    542    548    303   356    95    2290
# 76   2016-12   1498    366    344    207    239     74   103    25     650
# 88   2015-12   1151    232     88    129    186     29    54    10     313
# 100  2014-12    785    111     22    102    111     24    18     4     169
# 112  2013-12    475     20     12     61     24     20    12     4     108
# 124  2012-12    205     18     11     51      5     13     9     0      84
# 136  2011-12    103      4      7     24      2      6     7     0      39
# 148  2010-12     52      0      0      2      1      2     0     0       5
#
#         강원     충북     충남     전북     전남     경북     경남     제주      합계
# 0    18240  20009  24055  19804  24336  26985  36534  39535  547455
# 2    18236  19972  24130  19795  24200  26776  36225  39418  543900
# 4    14012  15140  16611  12727  15387  19154  22740  32976  389855
# 16    7946   8194   9991   7365   8708  11240  12606  25571  231443
# 28    4078   3883   5489   3323   5223   7051   6308  21285  134962
# 40    2445   2412   2841   1841   3326   4051   3626  18178   89918
# 52    1377   1199   1127    997   1974   2001   2107  15549   55756
# 64     459    281    336    336    960    756   1022   9206   25108
# 76     150     60    170     57    446    278    559   5629   10855
# 88      81     28    140     37    290    147    428   2369    5712
# 100     43     16    113     18    173    111    281    674    2775
# 112     20      8     94     13     98     62    131    302    1464
# 124     15      5     38      8     82     49     89    178     860
# 136     10      1      7      2     21     13     54     44     344
# 148      0      0      2      0      0      2      0      0      66

# %%
df_com =pd.read_csv('total_ev_power_demand.csv',encoding= 'utf8')

# %%
df_com.drop('ID',axis =1, inplace = True)

# %%
df_com
# Out:
#              YMD  EV_PWR_DEMAND_25  EV_PWR_DEMAND_50  EV_PWR_DEMAND_75  SGG_NM
# 0     2022-02-01          24174.80          25262.20          28078.60  강원 강릉시
# 1     2022-02-01           5147.14           5929.99           6501.83  강원 고성군
# 2     2022-02-01          16570.80          18122.10          40690.70  강원 동해시
# 3     2022-02-01          12587.10          12619.30          12695.20  강원 삼척시
# 4     2022-02-01          21754.30          23110.30          24899.20  강원 속초시
# ...          ...               ...               ...               ...     ...
# 5216  2023-12-01          14871.00          15630.80          18588.90  충북 제천시
# 5217  2023-12-01           3582.51           4578.46           5210.65  충북 증평군
# 5218  2023-12-01          23037.50          23476.40          24952.30  충북 진천군
# 5219  2023-12-01         207561.00         216169.00         233296.00  충북 청주시
# 5220  2023-12-01          77698.60          91270.00          93646.00  충북 충주시
#
# [5221 rows x 5 columns]

# %%
df_com['EV_PWR_DEMAND_25'] = df_com['EV_PWR_DEMAND_25'].round().astype(int)
df_com['EV_PWR_DEMAND_50'] = df_com['EV_PWR_DEMAND_50'].round().astype(int)
df_com['EV_PWR_DEMAND_75'] = df_com['EV_PWR_DEMAND_75'].round().astype(int)

# %%
df_com.to_csv('pre_resource.csv',encoding= 'cp949', index=False)

# %%
ev_4 = ev_3[['차종','주행거리(1회 충전 시)']]

# %%
ev_4.drop(ev_4[ev_4['차종'] == "2024 볼보 EX30"].index, inplace=True)
# Out:
# /tmp/ipykernel_451/826803142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_4.drop(ev_4[ev_4['차종'] == "2024 볼보 EX30"].index, inplace=True)

# %%
ev_4
# Out:
#                      차종 주행거리(1회 충전 시)
# 0          2024 테슬라 모델S         514km
# 1          2024 테슬라 모델3         435km
# 2      2024 대창모터스 다니고 W         186km
# 3      2024 대창모터스 다니고 T         175km
# 4      2024 대창모터스 다니고 R         186km
# ..                  ...           ...
# 64     2022 SS모터스 젤라 EV         194km
# 65         2022 코란도 이모션         307km
# 66  2022 DS 3 크로스백 E-텐스         260km
# 67     2022 아우디 e-트론 GT         362km
# 68  2022 아우디 RS e-트론 GT         336km
#
# [68 rows x 2 columns]

# %%
ev_4['주행거리(1회 충전 시)'] = ev_4['주행거리(1회 충전 시)'].str.replace('km','')
# Out:
# /tmp/ipykernel_451/156263891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_4['주행거리(1회 충전 시)'] = ev_4['주행거리(1회 충전 시)'].str.replace('km','')

# %%
ev_4['주행거리(1회 충전 시)'] = ev_4['주행거리(1회 충전 시)'].astype(int)
# Out:
# /tmp/ipykernel_451/398899479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_4['주행거리(1회 충전 시)'] = ev_4['주행거리(1회 충전 시)'].astype(int)

# %%
avg = ev_4['주행거리(1회 충전 시)'].sum() / 68

# %%
avg = int(avg)

# %%
new_data = {
    '차종' : ['평균'],
    '주행거리(1회 충전 시)' : [avg]
}

# %%
new_df = pd.DataFrame(new_data)

# %%
ev_4 = pd.concat([ev_4,new_df],ignore_index=True)

# %%
ev_4.rename(columns= {'주행거리(1회 충전 시)' : '주행거리(1회 충전 시,km)'},inplace=True)

# %%
ev_4.to_csv('car_list2.csv',encoding= 'cp949',index = False)

# %%
pre_charge = pd.read_csv('pre_resource.csv',encoding= 'cp949')

# %%
pre_charge
# Out:
#              YMD  EV_PWR_DEMAND_25  EV_PWR_DEMAND_50  EV_PWR_DEMAND_75  SGG_NM
# 0     2022-02-01             24175             25262             28079  강원 강릉시
# 1     2022-02-01              5147              5930              6502  강원 고성군
# 2     2022-02-01             16571             18122             40691  강원 동해시
# 3     2022-02-01             12587             12619             12695  강원 삼척시
# 4     2022-02-01             21754             23110             24899  강원 속초시
# ...          ...               ...               ...               ...     ...
# 5216  2023-12-01             14871             15631             18589  충북 제천시
# 5217  2023-12-01              3583              4578              5211  충북 증평군
# 5218  2023-12-01             23038             23476             24952  충북 진천군
# 5219  2023-12-01            207561            216169            233296  충북 청주시
# 5220  2023-12-01             77699             91270             93646  충북 충주시
#
# [5221 rows x 5 columns]

# %%
#pattern = r'[0-9]+-[0-9]'

# %%
pre_charge[['DO','SGG']] = pre_charge['SGG_NM'].apply(lambda x : pd.Series(x.split(' ')))

# %%
pre_charge.drop('SGG_NM',axis = 1, inplace = True)

# %%
pre_charge.drop('EV_PWR_DEMAND_75',axis = 1, inplace = True)

# %%
pre_charge.rename(columns= {'EV_PWR_DEMAND_50':'예측 수요량'},inplace= True)

# %%
pre_charge['일별 수요량'] = pre_charge['예측 수요량'].apply(lambda x : int(x / 30))

# %%
pre_charge.rename(columns={'YMD' : '연월', '예측 수요량' : '월별 수요량'},inplace = True)

# %%
pre_charge['연월'] = pre_charge['연월'].str.replace('-01','')

# %%
pre_charge = pre_charge[['연월','DO','SGG','월별 수요량','일별 수요량']]

# %%
pre_charge[['연','월']] = pre_charge['연월'].apply(lambda x : pd.Series(x.split('-')))

# %%
pre_charge = pre_charge[['연','월','DO','SGG','월별 수요량','일별 수요량','연월']]

# %%
pre_charge.rename(columns = {'DO' : '도', 'SGG' : '시군구'},inplace = True)

# %%
pre_charge.drop('연월', axis = 1, inplace = True)

# %%
pre_charge.dtypes
# Out:
# 연         object
# 월         object
# 도         object
# 시군구       object
# 월별 수요량     int64
# dtype: object

# %%
import pymysql

# %%
con =pymysql.connect(host='172.27.140.156', user='gen', password='encore', db='classicmodels', charset='utf8')
cur = con.cursor()

# %%
pre_charge.columns
# Out:
# Index(['연', '월', '도', '시군구', '월별 수요량'], dtype='object')

# %%
sql = '''CREATE TABLE pre_charge(
    연  CHAR(6) NOT NULL,
    월  CHAR(6) NOT NULL,
    도  CHAR(6) NOT NULL,
    시군구  CHAR(6) NOT NULL,
    월별_수요량  INT NOT NULL
)'''

# %%
pre_charge.dtypes
# Out:
# 연         object
# 월         object
# 도         object
# 시군구       object
# 월별 수요량     int64
# dtype: object

# %%
pre_charge['연'] = pre_charge['연'].astype(str)
pre_charge['월'] = pre_charge['월'].astype(str)
pre_charge['도'] = pre_charge['도'].astype(str)
pre_charge['시군구'] = pre_charge['시군구'].astype(str)

# %%
cur.execute(sql)
# Out:
# 0

# %%
pre_charge_melt = pd.melt(pre_charge, id_vars=['연', '월', '도', '시군구', '월별 수요량'])

# %%
sql = "INSERT INTO pre_charge VALUES (%s, %s, %s, %s, %s)"

# %%
pre_charge.apply(lambda x : cur.execute(sql, x.tolist()), axis=1)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5216    1
# 5217    1
# 5218    1
# 5219    1
# 5220    1
# Length: 5221, dtype: int64

# %%
con.commit()

# %%
con.close()
